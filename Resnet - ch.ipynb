# %%
pip install keras
# Out:
# Requirement already satisfied: keras in c:\users\youngjoo\anaconda3\lib\site-packages (2.4.3)
# Requirement already satisfied: scipy>=0.14 in c:\users\youngjoo\anaconda3\lib\site-packages (from keras) (1.5.2)
# Requirement already satisfied: numpy>=1.9.1 in c:\users\youngjoo\anaconda3\lib\site-packages (from keras) (1.19.2)
# Requirement already satisfied: pyyaml in c:\users\youngjoo\anaconda3\lib\site-packages (from keras) (5.3.1)
# Requirement already satisfied: h5py in c:\users\youngjoo\anaconda3\lib\site-packages (from keras) (2.10.0)
# Requirement already satisfied: six in c:\users\youngjoo\anaconda3\lib\site-packages (from h5py->keras) (1.15.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
from keras import layers
from keras.layers import Input,Add,Dense,Activation,ZeroPadding2D,BatchNormalization,Flatten,Conv2D,AveragePooling2D,MaxPooling2D,Dropout
from keras.models import Model,load_model
from keras.preprocessing import image
from keras.utils import layer_utils
from keras.utils.data_utils import get_file
from keras.applications.imagenet_utils import preprocess_input
import matplotlib.pyplot
from IPython.display import SVG
from keras.utils.vis_utils import model_to_dot
from keras.utils import plot_model

from keras.initializers import glorot_uniform
import scipy.misc
from matplotlib.pyplot import imshow

# %%
def identity_block(X,f,filters):
    F1,F2,F3 =filters
    X_shortcut=X
    
    X=Conv2D(filters=F1,kernel_size=(1,1),strides=(1,1),padding='valid')(X)
    X=BatchNormalization(axis=3)(X)
    X=Activation('relu')(X)
    
    X=Conv2D(filters=F2,kernel_size=(f,f),strides=(1,1),padding='same')(X)
    X=BatchNormalization(axis=3)(X)
    X=Activation('relu')(X)
    
    X=Conv2D(filters=F3,kernel_size=(1,1),strides=(1,1),padding='valid')(X)
    X=BatchNormalization(axis=3)(X)
    
    X=Add()([X,X_shortcut])
    X=Activation('relu')(X)
    
    return X

# %%
def convolutional_block(X,f,filters,s=2):
    F1,F2,F3 =filters
    X_shortcut=X
    
    X=Conv2D(filters=F1,kernel_size=(1,1),strides=(s,s))(X)
    X=BatchNormalization(axis=3)(X)
    X=Activation('relu')(X)
    
    X=Conv2D(filters=F2,kernel_size=(f,f),strides=(1,1),padding='same')(X)
    X=BatchNormalization(axis=3)(X)
    X=Activation('relu')(X)
    
    X=Conv2D(filters=F3,kernel_size=(1,1),strides=(1,1),padding='valid')(X)
    X=BatchNormalization(axis=3)(X)
    
    X_shortcut=Conv2D(filters=F3,kernel_size=(1,1),strides=(s,s),padding='valid')(X_shortcut)
    X_shortcut=BatchNormalization(axis=3)(X_shortcut)
    
    X=Add()([X,X_shortcut])
    X=Activation('relu')(X)
    
    return X

# %%
def ResNet50(input_shape=(224,224,3),classes=1):
    X_input=Input(input_shape)
    
    X=ZeroPadding2D((3,3))(X_input)
    #1
    X=Conv2D(64,(7,7),strides=(2,2))(X)
    X=BatchNormalization(axis=3)(X)
    X=Activation('relu')(X)
    X=MaxPooling2D((3,3),strides=(2,2))(X)
    
    #2
    X=convolutional_block(X,f=3,filters=[64,64,256],s=1)
    
    X=identity_block(X,3,[64,64,256])
    #3
    X=convolutional_block(X,f=3,filters=[128,128,512],s=2)
    X=identity_block(X,3,[128,128,512])
    #4
    X=convolutional_block(X,f=3,filters=[256,256,1024],s=2)
    X=identity_block(X,3,[256,256,1024])
    #5
    X=convolutional_block(X,f=3,filters=[512,512,2048],s=2)
    X=identity_block(X,3,[512,512,2048])
    #AVGPOOL
    X=AveragePooling2D((2,2),name="avg_pool")(X)
    
    #output layer
    X=Flatten()(X)
    X=Dense(classes,activation='sigmoid',name='fc'+str(classes),kernel_initializer = glorot_uniform(seed=0))(X)
    model.add(Dropout(0.5))
    model=Model(inputs=X_input,outputs=X,name='ResNet50')
    
    return model

# %%
model =ResNet50(input_shape=(224,224,3),classes=1)
model.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['acc'])
model.summary()
# Out:
# Model: "ResNet50"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# zero_padding2d (ZeroPadding2D)  (None, 230, 230, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 112, 112, 64) 9472        zero_padding2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 112, 112, 64) 256         conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 112, 112, 64) 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 55, 55, 64)   0           activation[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 55, 55, 64)   4160        max_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 55, 55, 64)   256         conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 55, 55, 64)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 55, 55, 64)   36928       activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 55, 55, 64)   256         conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 55, 55, 64)   0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 55, 55, 256)  16640       activation_2[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 55, 55, 256)  16640       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 55, 55, 256)  1024        conv2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 55, 55, 256)  1024        conv2d_4[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 55, 55, 256)  0           batch_normalization_3[0][0]
#                                                                  batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 55, 55, 256)  0           add[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 55, 55, 64)   16448       activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 55, 55, 64)   256         conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 55, 55, 64)   0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 55, 55, 64)   36928       activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 55, 55, 64)   256         conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 55, 55, 64)   0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 55, 55, 256)  16640       activation_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 55, 55, 256)  1024        conv2d_7[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 55, 55, 256)  0           batch_normalization_7[0][0]
#                                                                  activation_3[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 55, 55, 256)  0           add_1[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 28, 28, 128)  32896       activation_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 28, 28, 128)  512         conv2d_8[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 28, 28, 128)  0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 28, 28, 128)  147584      activation_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 28, 28, 128)  512         conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 28, 28, 128)  0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 28, 28, 512)  66048       activation_8[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 28, 28, 512)  131584      activation_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 28, 28, 512)  2048        conv2d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 28, 28, 512)  2048        conv2d_11[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 28, 28, 512)  0           batch_normalization_10[0][0]
#                                                                  batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 28, 28, 512)  0           add_2[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 28, 28, 128)  65664       activation_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 28, 28, 128)  512         conv2d_12[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 28, 28, 128)  0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 28, 28, 128)  147584      activation_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 28, 28, 128)  512         conv2d_13[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 28, 28, 128)  0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 28, 28, 512)  66048       activation_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 28, 28, 512)  2048        conv2d_14[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 28, 28, 512)  0           batch_normalization_14[0][0]
#                                                                  activation_9[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 28, 28, 512)  0           add_3[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 14, 14, 256)  131328      activation_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 14, 14, 256)  1024        conv2d_15[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 14, 14, 256)  0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 14, 14, 256)  590080      activation_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 14, 14, 256)  1024        conv2d_16[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 14, 14, 256)  0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 14, 14, 1024) 263168      activation_14[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 14, 14, 1024) 525312      activation_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 14, 14, 1024) 4096        conv2d_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 14, 14, 1024) 4096        conv2d_18[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 14, 14, 1024) 0           batch_normalization_17[0][0]
#                                                                  batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 14, 14, 1024) 0           add_4[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 14, 14, 256)  262400      activation_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 14, 14, 256)  1024        conv2d_19[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 14, 14, 256)  0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 14, 14, 256)  590080      activation_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 14, 14, 256)  1024        conv2d_20[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 14, 14, 256)  0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 14, 14, 1024) 263168      activation_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 14, 14, 1024) 4096        conv2d_21[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 14, 14, 1024) 0           batch_normalization_21[0][0]
#                                                                  activation_15[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 14, 14, 1024) 0           add_5[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 7, 7, 512)    524800      activation_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 7, 7, 512)    2048        conv2d_22[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 7, 7, 512)    0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 7, 7, 512)    2359808     activation_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 7, 7, 512)    2048        conv2d_23[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 7, 7, 512)    0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 7, 7, 2048)   1050624     activation_20[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 7, 7, 2048)   2099200     activation_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 7, 7, 2048)   8192        conv2d_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 7, 7, 2048)   8192        conv2d_25[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 7, 7, 2048)   0           batch_normalization_24[0][0]
#                                                                  batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 7, 7, 2048)   0           add_6[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 7, 7, 512)    1049088     activation_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 7, 7, 512)    2048        conv2d_26[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 7, 7, 512)    0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 7, 7, 512)    2359808     activation_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 7, 7, 512)    2048        conv2d_27[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 7, 7, 512)    0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 7, 7, 2048)   1050624     activation_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 7, 7, 2048)   8192        conv2d_28[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 7, 7, 2048)   0           batch_normalization_28[0][0]
#                                                                  activation_21[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 7, 7, 2048)   0           add_7[0][0]
# __________________________________________________________________________________________________
# avg_pool (AveragePooling2D)     (None, 3, 3, 2048)   0           activation_24[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 18432)        0           avg_pool[0][0]
# __________________________________________________________________________________________________
# fc1 (Dense)                     (None, 1)            18433       flatten[0][0]
# ==================================================================================================
# Total params: 14,010,881
# Trainable params: 13,980,033
# Non-trainable params: 30,848
# __________________________________________________________________________________________________

# %%
from IPython.display import Image, display, clear_output
import numpy as np
import pandas as pd
import os
from tensorflow.keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
from tensorflow.keras.applications.imagenet_utils import preprocess_input, decode_predictions
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.image import ImageDataGenerator


train_datagen = ImageDataGenerator(rescale=1./255)   # 모든 이미지를 1/255로 스케일을 조정합니다
test_datagen = ImageDataGenerator(rescale=1./255)

train_dir = "car-damage-dataset/data1a/training"
validation_dir = 'car-damage-dataset/data1a/validation'

train_generator = train_datagen.flow_from_directory( \
        train_dir,         # 타깃 디렉터리
        target_size=(224, 224),             # 모든 이미지를 224 × 224 크기
        batch_size=20 ,
        class_mode='binary')
validation_generator = test_datagen.flow_from_directory(
        validation_dir,
        target_size=(224, 224),
        batch_size=20,
        class_mode='binary')
for data_batch, labels_batch in train_generator:
    print('배치 데이터 크기:', data_batch.shape)
    print('배치 레이블 크기:', labels_batch.shape)
    print('배치 레이블:', labels_batch[0])
    break
    
import matplotlib.pyplot as plt
plt.imshow( train_generator[0][0][0])
plt.show()
# Out:
# Found 1840 images belonging to 2 classes.
# Found 460 images belonging to 2 classes.
# 배치 데이터 크기: (20, 224, 224, 3)
# 배치 레이블 크기: (20,)
# 배치 레이블: 0.0

# %%
###########################################################
# 학습
###########################################################
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping


checkpoint = ModelCheckpoint ( "resnet - ch_model.h5", monitor = 'val_acc', verbose = 1, save_best_only = True, save_weights_only = False, mode = 'auto', period = 1)
early = EarlyStopping (monitor = 'val_acc', min_delta = 0,patience = 20, verbose = 1, mode = 'auto')


history = model.fit_generator(steps_per_epoch=(1840/20),
                              generator=train_generator, 
                              validation_data= validation_generator, 
                              validation_steps=(460/20),
                              epochs=5,
                              callbacks=[checkpoint,early])

# history = model.fit_generator(train_generator,
#                              steps_per_epoch=int(1840/20),
#                              epochs = 5,
#                              validation_data = validation_generator,
#                              validation_steps =int(460/20))

 



###########################################################
# 학습 결과 정확도 및 비용 그래프
###########################################################
import matplotlib.pyplot as plt 

acc = history.history['acc']
val_acc = history.history['val_acc']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))
plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()
plt.figure()

plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()
plt.show()

########################################################
import matplotlib.pyplot as plt
# print( model.predict( [[  train_generator[10][0][0] ]]) ) #
# plt.imshow(  train_generator[10][0][0] )
# plt.show()
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# C:\Users\youngjoo\anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py:1844: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/5
# 92/92 [==============================] - 1027s 11s/step - loss: 2.0809 - acc: 0.5547 - val_loss: 1.0798 - val_acc: 0.5000
#
# Epoch 00001: val_acc improved from -inf to 0.50000, saving model to resnet - ch_model.h5
# Epoch 2/5
# 92/92 [==============================] - 952s 10s/step - loss: 1.1413 - acc: 0.6854 - val_loss: 1.1509 - val_acc: 0.5000
#
# Epoch 00002: val_acc did not improve from 0.50000
# Epoch 3/5
# 92/92 [==============================] - 989s 11s/step - loss: 0.6968 - acc: 0.7562 - val_loss: 1.0170 - val_acc: 0.5043
#
# Epoch 00003: val_acc improved from 0.50000 to 0.50435, saving model to resnet - ch_model.h5
# Epoch 4/5
# 92/92 [==============================] - 1155s 13s/step - loss: 0.7977 - acc: 0.6886 - val_loss: 64.0280 - val_acc: 0.5109
#
# Epoch 00004: val_acc improved from 0.50435 to 0.51087, saving model to resnet - ch_model.h5
# Epoch 5/5
# 92/92 [==============================] - 1092s 12s/step - loss: 0.8786 - acc: 0.6767 - val_loss: 0.8698 - val_acc: 0.6283
#
# Epoch 00005: val_acc improved from 0.51087 to 0.62826, saving model to resnet - ch_model.h5

# %%
###########################################################
# 학습
###########################################################
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping


checkpoint = ModelCheckpoint ( "resnet - ch_model.h5", monitor = 'val_acc', verbose = 1, save_best_only = True, save_weights_only = False, mode = 'auto', period = 1)
early = EarlyStopping (monitor = 'val_acc', min_delta = 0,patience = 20, verbose = 1, mode = 'auto')


history = model.fit_generator(steps_per_epoch=10,
                              generator=train_generator, 
                              validation_data= validation_generator, 
                              validation_steps=10,
                              epochs=50,
                              callbacks=[checkpoint,early])

# history = model.fit_generator(train_generator,
#                              steps_per_epoch=int(1840/20),
#                              epochs = 5,
#                              validation_data = validation_generator,
#                              validation_steps =int(460/20))

 



###########################################################
# 학습 결과 정확도 및 비용 그래프
###########################################################
import matplotlib.pyplot as plt 

acc = history.history['acc']
val_acc = history.history['val_acc']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))
plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()
plt.figure()

plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()
plt.show()

########################################################
import matplotlib.pyplot as plt
# print( model.predict( [[  train_generator[10][0][0] ]]) ) #
# plt.imshow(  train_generator[10][0][0] )
# plt.show()
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/50
# 10/10 [==============================] - 100s 10s/step - loss: 0.5556 - acc: 0.7550 - val_loss: 0.9572 - val_acc: 0.6550
#
# Epoch 00001: val_acc improved from -inf to 0.65500, saving model to resnet - ch_model.h5
# Epoch 2/50
# 10/10 [==============================] - 123s 13s/step - loss: 0.5438 - acc: 0.7850 - val_loss: 1.3873 - val_acc: 0.6100
#
# Epoch 00002: val_acc did not improve from 0.65500
# Epoch 3/50
# 10/10 [==============================] - 133s 14s/step - loss: 0.5686 - acc: 0.7400 - val_loss: 0.7347 - val_acc: 0.5900
#
# Epoch 00003: val_acc did not improve from 0.65500
# Epoch 4/50
# 10/10 [==============================] - 152s 16s/step - loss: 0.5230 - acc: 0.7550 - val_loss: 0.6226 - val_acc: 0.6700
#
# Epoch 00004: val_acc improved from 0.65500 to 0.67000, saving model to resnet - ch_model.h5
# Epoch 5/50
# 10/10 [==============================] - 146s 15s/step - loss: 0.4653 - acc: 0.7800 - val_loss: 1.7140 - val_acc: 0.6000
#
# Epoch 00005: val_acc did not improve from 0.67000
# Epoch 6/50
# 10/10 [==============================] - 144s 15s/step - loss: 0.4684 - acc: 0.8100 - val_loss: 1.6538 - val_acc: 0.5800
#
# Epoch 00006: val_acc did not improve from 0.67000
# Epoch 7/50
# 10/10 [==============================] - 140s 14s/step - loss: 0.4905 - acc: 0.8000 - val_loss: 0.7431 - val_acc: 0.6500
#
# Epoch 00007: val_acc did not improve from 0.67000
# Epoch 8/50
# 10/10 [==============================] - 124s 12s/step - loss: 0.4872 - acc: 0.8050 - val_loss: 0.6014 - val_acc: 0.6900
#
# Epoch 00008: val_acc improved from 0.67000 to 0.69000, saving model to resnet - ch_model.h5
# Epoch 9/50
# 10/10 [==============================] - 140s 14s/step - loss: 0.4359 - acc: 0.8000 - val_loss: 0.6258 - val_acc: 0.7400
#
# Epoch 00009: val_acc improved from 0.69000 to 0.74000, saving model to resnet - ch_model.h5
# Epoch 10/50
# 10/10 [==============================] - 126s 12s/step - loss: 0.4615 - acc: 0.7650 - val_loss: 0.5879 - val_acc: 0.6900
#
# Epoch 00010: val_acc did not improve from 0.74000
# Epoch 11/50
# 10/10 [==============================] - 115s 11s/step - loss: 0.3988 - acc: 0.8250 - val_loss: 0.8683 - val_acc: 0.6400
#
# Epoch 00011: val_acc did not improve from 0.74000
# Epoch 12/50
# 10/10 [==============================] - 118s 12s/step - loss: 0.4290 - acc: 0.7900 - val_loss: 1.8441 - val_acc: 0.5350
#
# Epoch 00012: val_acc did not improve from 0.74000
# Epoch 13/50
# 10/10 [==============================] - 139s 14s/step - loss: 0.4446 - acc: 0.8150 - val_loss: 2.7869 - val_acc: 0.5600
#
# Epoch 00013: val_acc did not improve from 0.74000
# Epoch 14/50
# 10/10 [==============================] - 121s 12s/step - loss: 0.4283 - acc: 0.8350 - val_loss: 0.8229 - val_acc: 0.6850
#
# Epoch 00014: val_acc did not improve from 0.74000
# Epoch 15/50
# 10/10 [==============================] - 113s 11s/step - loss: 0.3132 - acc: 0.8800 - val_loss: 0.6827 - val_acc: 0.7450
#
# Epoch 00015: val_acc improved from 0.74000 to 0.74500, saving model to resnet - ch_model.h5
# Epoch 16/50
# 10/10 [==============================] - 110s 11s/step - loss: 0.3070 - acc: 0.8700 - val_loss: 1.5562 - val_acc: 0.5750
#
# Epoch 00016: val_acc did not improve from 0.74500
# Epoch 17/50
# 10/10 [==============================] - 107s 11s/step - loss: 0.5508 - acc: 0.7800 - val_loss: 0.6648 - val_acc: 0.7100
#
# Epoch 00017: val_acc did not improve from 0.74500
# Epoch 18/50
# 10/10 [==============================] - 114s 12s/step - loss: 0.3336 - acc: 0.8550 - val_loss: 1.0964 - val_acc: 0.6400
#
# Epoch 00018: val_acc did not improve from 0.74500
# Epoch 19/50
# 10/10 [==============================] - 141s 15s/step - loss: 0.3509 - acc: 0.8400 - val_loss: 1.7121 - val_acc: 0.5700
#
# Epoch 00019: val_acc did not improve from 0.74500
# Epoch 20/50
# 10/10 [==============================] - 117s 12s/step - loss: 0.3842 - acc: 0.8250 - val_loss: 1.0666 - val_acc: 0.6550
#
# Epoch 00020: val_acc did not improve from 0.74500
# Epoch 21/50
# 10/10 [==============================] - 107s 11s/step - loss: 0.3251 - acc: 0.8500 - val_loss: 0.6336 - val_acc: 0.7100
#
# Epoch 00021: val_acc did not improve from 0.74500
# Epoch 22/50
# 10/10 [==============================] - 116s 12s/step - loss: 0.2998 - acc: 0.8700 - val_loss: 0.7481 - val_acc: 0.7100
#
# Epoch 00022: val_acc did not improve from 0.74500
# Epoch 23/50
# 10/10 [==============================] - 115s 12s/step - loss: 0.3481 - acc: 0.8200 - val_loss: 0.6620 - val_acc: 0.6950
#
# Epoch 00023: val_acc did not improve from 0.74500
# Epoch 24/50
# 10/10 [==============================] - 99s 10s/step - loss: 0.3364 - acc: 0.8550 - val_loss: 0.5622 - val_acc: 0.7550
#
# Epoch 00024: val_acc improved from 0.74500 to 0.75500, saving model to resnet - ch_model.h5
# Epoch 25/50
# 10/10 [==============================] - 130s 13s/step - loss: 0.2840 - acc: 0.8800 - val_loss: 0.7570 - val_acc: 0.6350
#
# Epoch 00025: val_acc did not improve from 0.75500
# Epoch 26/50
# 10/10 [==============================] - 114s 11s/step - loss: 0.3257 - acc: 0.8700 - val_loss: 0.7267 - val_acc: 0.6650
#
# Epoch 00026: val_acc did not improve from 0.75500
# Epoch 27/50
# 10/10 [==============================] - 117s 12s/step - loss: 0.2533 - acc: 0.9000 - val_loss: 0.4983 - val_acc: 0.7500
#
# Epoch 00027: val_acc did not improve from 0.75500
# Epoch 28/50
# 10/10 [==============================] - 117s 12s/step - loss: 0.2320 - acc: 0.8850 - val_loss: 0.9174 - val_acc: 0.6800
#
# Epoch 00028: val_acc did not improve from 0.75500
# Epoch 29/50
# 10/10 [==============================] - 101s 10s/step - loss: 0.2291 - acc: 0.9100 - val_loss: 2.2801 - val_acc: 0.5850
#
# Epoch 00029: val_acc did not improve from 0.75500
# Epoch 30/50
# 10/10 [==============================] - 112s 11s/step - loss: 0.2535 - acc: 0.8950 - val_loss: 0.6964 - val_acc: 0.7250
#
# Epoch 00030: val_acc did not improve from 0.75500
# Epoch 31/50
# 10/10 [==============================] - 120s 12s/step - loss: 0.2323 - acc: 0.9150 - val_loss: 0.8481 - val_acc: 0.7200
#
# Epoch 00031: val_acc did not improve from 0.75500
# Epoch 32/50
# 10/10 [==============================] - 132s 14s/step - loss: 0.2474 - acc: 0.9050 - val_loss: 0.7837 - val_acc: 0.7250
#
# Epoch 00032: val_acc did not improve from 0.75500
# Epoch 33/50
# 10/10 [==============================] - 134s 14s/step - loss: 0.1649 - acc: 0.9350 - val_loss: 0.7863 - val_acc: 0.7550
#
# Epoch 00033: val_acc did not improve from 0.75500
# Epoch 34/50
# 10/10 [==============================] - 136s 14s/step - loss: 0.2024 - acc: 0.9050 - val_loss: 0.5960 - val_acc: 0.7700
#
# Epoch 00034: val_acc improved from 0.75500 to 0.77000, saving model to resnet - ch_model.h5
# Epoch 35/50
# 10/10 [==============================] - 142s 15s/step - loss: 0.2003 - acc: 0.9200 - val_loss: 0.7709 - val_acc: 0.7100
#
# Epoch 00035: val_acc did not improve from 0.77000
# Epoch 36/50
# 10/10 [==============================] - 142s 14s/step - loss: 0.2416 - acc: 0.9150 - val_loss: 0.5065 - val_acc: 0.7750
#
# Epoch 00036: val_acc improved from 0.77000 to 0.77500, saving model to resnet - ch_model.h5
# Epoch 37/50
# 10/10 [==============================] - 145s 15s/step - loss: 0.3075 - acc: 0.9000 - val_loss: 0.6004 - val_acc: 0.7500
#
# Epoch 00037: val_acc did not improve from 0.77500
# Epoch 38/50
# 10/10 [==============================] - 122s 12s/step - loss: 0.3072 - acc: 0.8600 - val_loss: 0.8162 - val_acc: 0.7350
#
# Epoch 00038: val_acc did not improve from 0.77500
# Epoch 39/50
# 10/10 [==============================] - 134s 14s/step - loss: 0.2465 - acc: 0.9050 - val_loss: 0.4478 - val_acc: 0.8300
#
# Epoch 00039: val_acc improved from 0.77500 to 0.83000, saving model to resnet - ch_model.h5
# Epoch 40/50
# 10/10 [==============================] - 125s 13s/step - loss: 0.2026 - acc: 0.9050 - val_loss: 0.9145 - val_acc: 0.6650
#
# Epoch 00040: val_acc did not improve from 0.83000
# Epoch 41/50
# 10/10 [==============================] - 115s 12s/step - loss: 0.1684 - acc: 0.9200 - val_loss: 0.7887 - val_acc: 0.7200
#
# Epoch 00041: val_acc did not improve from 0.83000
# Epoch 42/50
# 10/10 [==============================] - 119s 12s/step - loss: 0.2219 - acc: 0.9050 - val_loss: 0.8415 - val_acc: 0.7000
#
# Epoch 00042: val_acc did not improve from 0.83000
# Epoch 43/50
# 10/10 [==============================] - 134s 14s/step - loss: 0.2315 - acc: 0.9150 - val_loss: 0.5362 - val_acc: 0.7500
#
# Epoch 00043: val_acc did not improve from 0.83000
# Epoch 44/50
# 10/10 [==============================] - 136s 14s/step - loss: 0.2433 - acc: 0.9250 - val_loss: 0.7890 - val_acc: 0.7050
#
# Epoch 00044: val_acc did not improve from 0.83000
# Epoch 45/50
# 10/10 [==============================] - 138s 14s/step - loss: 0.1717 - acc: 0.9250 - val_loss: 0.6104 - val_acc: 0.7500
#
# Epoch 00045: val_acc did not improve from 0.83000
# Epoch 46/50
# 10/10 [==============================] - 151s 16s/step - loss: 0.1858 - acc: 0.9350 - val_loss: 0.5502 - val_acc: 0.8000
#
# Epoch 00046: val_acc did not improve from 0.83000
# Epoch 47/50
# 10/10 [==============================] - 130s 13s/step - loss: 0.1881 - acc: 0.9350 - val_loss: 0.6785 - val_acc: 0.7700
#
# Epoch 00047: val_acc did not improve from 0.83000
# Epoch 48/50
# 10/10 [==============================] - 138s 14s/step - loss: 0.2107 - acc: 0.9300 - val_loss: 0.5785 - val_acc: 0.7750
#
# Epoch 00048: val_acc did not improve from 0.83000
# Epoch 49/50
# 10/10 [==============================] - 136s 14s/step - loss: 0.1418 - acc: 0.9450 - val_loss: 0.5438 - val_acc: 0.7850
#
# Epoch 00049: val_acc did not improve from 0.83000
# Epoch 50/50
# 10/10 [==============================] - 127s 13s/step - loss: 0.2219 - acc: 0.9250 - val_loss: 0.6977 - val_acc: 0.7100
#
# Epoch 00050: val_acc did not improve from 0.83000

# %%
###########################################################
# 학습
###########################################################
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping


checkpoint = ModelCheckpoint ( "resnet - ch_model.h5", monitor = 'val_acc', verbose = 1, save_best_only = True, save_weights_only = False, mode = 'auto', period = 1)
early = EarlyStopping (monitor = 'val_acc', min_delta = 0,patience = 20, verbose = 1, mode = 'auto')


history = model.fit_generator(steps_per_epoch=10,
                              generator=train_generator, 
                              validation_data= validation_generator, 
                              validation_steps=10,
                              epochs=50,
                              callbacks=[checkpoint,early])

# history = model.fit_generator(train_generator,
#                              steps_per_epoch=int(1840/20),
#                              epochs = 5,
#                              validation_data = validation_generator,
#                              validation_steps =int(460/20))

 



###########################################################
# 학습 결과 정확도 및 비용 그래프
###########################################################
import matplotlib.pyplot as plt 

acc = history.history['acc']
val_acc = history.history['val_acc']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))
plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()
plt.figure()

plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()
plt.show()

########################################################
import matplotlib.pyplot as plt
# print( model.predict( [[  train_generator[10][0][0] ]]) ) #
# plt.imshow(  train_generator[10][0][0] )
# plt.show()
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/50
# 10/10 [==============================] - 240s 23s/step - loss: 0.1767 - acc: 0.9400 - val_loss: 0.6416 - val_acc: 0.7300
#
# Epoch 00001: val_acc improved from -inf to 0.73000, saving model to resnet - ch_model.h5
# Epoch 2/50
# 10/10 [==============================] - 264s 27s/step - loss: 0.2341 - acc: 0.9150 - val_loss: 0.8232 - val_acc: 0.7450
#
# Epoch 00002: val_acc improved from 0.73000 to 0.74500, saving model to resnet - ch_model.h5
# Epoch 3/50
# 10/10 [==============================] - 251s 26s/step - loss: 0.1702 - acc: 0.9150 - val_loss: 0.7788 - val_acc: 0.7300
#
# Epoch 00003: val_acc did not improve from 0.74500
# Epoch 4/50
# 10/10 [==============================] - 248s 25s/step - loss: 0.1915 - acc: 0.9350 - val_loss: 2.2134 - val_acc: 0.5750
#
# Epoch 00004: val_acc did not improve from 0.74500
# Epoch 5/50
# 10/10 [==============================] - 264s 26s/step - loss: 0.1521 - acc: 0.9450 - val_loss: 1.3070 - val_acc: 0.6550
#
# Epoch 00005: val_acc did not improve from 0.74500
# Epoch 6/50
# 10/10 [==============================] - 254s 26s/step - loss: 0.1536 - acc: 0.9300 - val_loss: 1.2322 - val_acc: 0.6900
#
# Epoch 00006: val_acc did not improve from 0.74500
# Epoch 7/50
# 10/10 [==============================] - 290s 30s/step - loss: 0.1680 - acc: 0.9300 - val_loss: 4.2408 - val_acc: 0.5900
#
# Epoch 00007: val_acc did not improve from 0.74500
# Epoch 8/50
# 10/10 [==============================] - 340s 35s/step - loss: 0.1273 - acc: 0.9500 - val_loss: 3.9356 - val_acc: 0.5250
#
# Epoch 00008: val_acc did not improve from 0.74500
# Epoch 9/50
# 10/10 [==============================] - 273s 28s/step - loss: 0.1887 - acc: 0.9300 - val_loss: 0.8856 - val_acc: 0.6800
#
# Epoch 00009: val_acc did not improve from 0.74500
# Epoch 10/50
# 10/10 [==============================] - 254s 25s/step - loss: 0.1574 - acc: 0.9350 - val_loss: 0.6343 - val_acc: 0.7750
#
# Epoch 00010: val_acc improved from 0.74500 to 0.77500, saving model to resnet - ch_model.h5
# Epoch 11/50
# 10/10 [==============================] - 274s 28s/step - loss: 0.1241 - acc: 0.9550 - val_loss: 0.8178 - val_acc: 0.7750
#
# Epoch 00011: val_acc did not improve from 0.77500
# Epoch 12/50
# 10/10 [==============================] - 304s 30s/step - loss: 0.0952 - acc: 0.9750 - val_loss: 1.3325 - val_acc: 0.7200
#
# Epoch 00012: val_acc did not improve from 0.77500
# Epoch 13/50
# 10/10 [==============================] - 259s 27s/step - loss: 0.1227 - acc: 0.9550 - val_loss: 1.5662 - val_acc: 0.6550
#
# Epoch 00013: val_acc did not improve from 0.77500
# Epoch 14/50
# 10/10 [==============================] - 254s 26s/step - loss: 0.0878 - acc: 0.9650 - val_loss: 1.9349 - val_acc: 0.6600
#
# Epoch 00014: val_acc did not improve from 0.77500
# Epoch 15/50
#  8/10 [=======================>......] - ETA: 43s - loss: 0.1267 - acc: 0.9750
